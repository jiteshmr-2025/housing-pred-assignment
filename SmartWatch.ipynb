# %% [markdown]
# <a href="https://colab.research.google.com/github/jiteshmr-2025/smartwatch-data-ass/blob/main/SmartWatch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python3 --version
# Out:
# Python 3.12.12

# %% [markdown]
# # Step 1: Loading the dataset
# Extract data from kaggle, and load it as a pandas DataFrame

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
